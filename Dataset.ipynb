# %%
import pandas as pd

# %%
table_1 = pd.read_csv("Table 1.csv")
table_2 = pd.read_csv("Table 2.csv")
table_3 = pd.read_csv("Table 3.csv")

# %%
table_1
# Out:
#      Full Date    Time  time_conv  time_index  Week          City Home Team  \
# 0   2008-09-04  7:08PM       1900          18     1      New York    Giants
# 1   2008-09-07  1:02PM       1300          12     1  Philadelphia    Eagles
# 2   2008-09-07  1:02PM       1300          12     1         Miami  Dolphins
# 3   2008-09-07  1:02PM       1300          12     1   New England  Patriots
# 4   2008-09-07  1:02PM       1300          12     1    Pittsburgh  Steelers
# ..         ...     ...        ...         ...   ...           ...       ...
# 75  2008-10-19  1:02PM       1300          12     7      New York    Giants
# 76  2008-10-19  1:02PM       1300          12     7       Chicago     Bears
# 77  2008-10-19  1:04PM       1300          12     7    Cincinnati   Bengals
# 78  2008-10-19  1:04PM       1300          12     7      Carolina  Panthers
# 79  2008-10-19  4:15PM       1600          15     7       Oakland   Raiders
#
#       Winner  Latitude  Longitude  Starting Game Temp (F)  \
# 0     Giants     40.43     -74.01                    72.0
# 1     Eagles     39.57     -75.07                    82.0
# 2       Jets     25.46     -80.12                    59.0
# 3   Patriots     42.21     -71.04                    82.0
# 4   Steelers     40.26     -80.00                    72.0
# ..       ...       ...        ...                     ...
# 75    Giants     40.43     -74.01                    68.0
# 76     Bears     41.53     -87.38                    86.0
# 77  Steelers     39.06     -84.31                    81.0
# 78  Panthers     35.14     -80.50                    55.0
# 79   Raiders     37.47    -122.13                    56.0
#
#                        weatherDesc  cloudcover
# 0               {'value': 'Clear'}         0.0
# 1       {'value': 'Partly cloudy'}        38.0
# 2   {'value': 'Light rain shower'}        97.0
# 3       {'value': 'Partly cloudy'}        38.0
# 4               {'value': 'Sunny'}        14.0
# ..                             ...         ...
# 75              {'value': 'Sunny'}         0.0
# 76              {'value': 'Sunny'}         5.0
# 77              {'value': 'Sunny'}        15.0
# 78              {'value': 'Sunny'}         9.0
# 79           {'value': 'Overcast'}       100.0
#
# [80 rows x 13 columns]

# %%
merged = pd.concat([table_1,table_2,table_3], axis=0)
merged
# Out:
#       Full Date    Time  time_conv  time_index Week           City  Home Team  \
# 0    2008-09-04  7:08PM       1900          18    1       New York     Giants
# 1    2008-09-07  1:02PM       1300          12    1   Philadelphia     Eagles
# 2    2008-09-07  1:02PM       1300          12    1          Miami   Dolphins
# 3    2008-09-07  1:02PM       1300          12    1    New England   Patriots
# 4    2008-09-07  1:02PM       1300          12    1     Pittsburgh   Steelers
# ..          ...     ...        ...         ...  ...            ...        ...
# 335  2010-10-10  4:05PM       1600          15    5        Arizona  Cardinals
# 336  2010-10-10  4:15PM       1600          15    5        Oakland    Raiders
# 337  2010-10-10  8:30PM       2000          19    5  San Francisco      49ers
# 338  2010-10-11  9:15PM       2100          20    5       New York       Jets
# 339  2010-10-17  1:00PM       1300          12    6      St. Louis       Rams
#
#         Winner  Latitude  Longitude  Starting Game Temp (F)  \
# 0       Giants     40.43     -74.01                    72.0
# 1       Eagles     39.57     -75.07                    82.0
# 2         Jets     25.46     -80.12                    59.0
# 3     Patriots     42.21     -71.04                    82.0
# 4     Steelers     40.26     -80.00                    72.0
# ..         ...       ...        ...                     ...
# 335  Cardinals     33.27    -112.05                    68.0
# 336    Raiders     37.47    -122.13                    59.0
# 337     Eagles     37.48    -122.24                    55.0
# 338       Jets     40.43     -74.01                    56.0
# 339       Rams     38.38     -90.11                    71.0
#
#                         weatherDesc  cloudcover
# 0                {'value': 'Clear'}         0.0
# 1        {'value': 'Partly cloudy'}        38.0
# 2    {'value': 'Light rain shower'}        97.0
# 3        {'value': 'Partly cloudy'}        38.0
# 4                {'value': 'Sunny'}        14.0
# ..                              ...         ...
# 335  {'value': 'Light rain shower'}        53.0
# 336      {'value': 'Partly cloudy'}        25.0
# 337              {'value': 'Clear'}        10.0
# 338      {'value': 'Partly cloudy'}        31.0
# 339              {'value': 'Sunny'}         3.0
#
# [840 rows x 13 columns]
