# %%
import requests
import pandas as pd
import json
from json import JSONDecoder
from pprint import pprint
import time as T

# %%
# http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=6f2d4be584aa413f9df230512210306&q=45.53,87.38&date=2008-09-08&tp=1&format=json
# above is example

# %%
#import cleaned NFL schedule
schedule_csv = "NFL_Schedule.csv"

schedule = pd.read_csv(schedule_csv)
schedule.head()
# Out:
#     Full Date    Time  time_conv  time_index Week          City Home Team  \
# 0  2008-09-04  7:08PM       1900          18    1      New York    Giants
# 1  2008-09-07  1:02PM       1300          12    1  Philadelphia    Eagles
# 2  2008-09-07  1:02PM       1300          12    1         Miami  Dolphins
# 3  2008-09-07  1:02PM       1300          12    1   New England  Patriots
# 4  2008-09-07  1:02PM       1300          12    1    Pittsburgh  Steelers
#
#      Winner
# 0    Giants
# 1    Eagles
# 2      Jets
# 3  Patriots
# 4  Steelers

# %%
#import cleaned NFL Stadium Locations
locations_csv = "NFL_Locations.csv"
locations = pd.read_csv(locations_csv)
#locations

# %%
locations["Latitude"] = locations["Latitude"].round(decimals=3)
locations["Longitude"] = locations["Longitude"].round(decimals=3)
#locations

# %%
#merge schedule with locations
merge = pd.merge(left=schedule, right=locations, how="left", left_on="City", right_on="Franchise")
merge.head()
# Out:
#     Full Date    Time  time_conv  time_index Week          City Home Team  \
# 0  2008-09-04  7:08PM       1900          18    1      New York    Giants
# 1  2008-09-07  1:02PM       1300          12    1  Philadelphia    Eagles
# 2  2008-09-07  1:02PM       1300          12    1         Miami  Dolphins
# 3  2008-09-07  1:02PM       1300          12    1   New England  Patriots
# 4  2008-09-07  1:02PM       1300          12    1    Pittsburgh  Steelers
#
#      Winner     Franchise  Latitude  Longitude
# 0    Giants      New York     40.43     -74.01
# 1    Eagles  Philadelphia     39.57     -75.07
# 2      Jets         Miami     25.46     -80.12
# 3  Patriots   New England     42.21     -71.04
# 4  Steelers    Pittsburgh     40.26     -80.00

# %%
clean_df = merge[["Full Date","Time","time_conv","time_index","Week","City","Home Team","Winner","Latitude","Longitude"]]
clean_df["Starting Game Temp (F)"] = ""
clean_df["weatherDesc"] = ""
clean_df["cloudcover"] = ""
clean_df
# Out:
#        Full Date    Time  time_conv  time_index       Week          City  \
# 0     2008-09-04  7:08PM       1900          18          1      New York
# 1     2008-09-07  1:02PM       1300          12          1  Philadelphia
# 2     2008-09-07  1:02PM       1300          12          1         Miami
# 3     2008-09-07  1:02PM       1300          12          1   New England
# 4     2008-09-07  1:02PM       1300          12          1    Pittsburgh
# ...          ...     ...        ...         ...        ...           ...
# 1732  2015-01-17  1:06PM       1300          12   Division      Carolina
# 1733  2015-01-17  4:40PM       1600          15   Division        Denver
# 1734  2015-01-24  3:05PM       1500          14  ConfChamp        Denver
# 1735  2015-01-24  6:42PM       1800          17  ConfChamp      Carolina
# 1736  2015-02-07  6:39PM       1800          17  SuperBowl        Denver
#
#      Home Team    Winner  Latitude  Longitude Starting Game Temp (F)  \
# 0       Giants    Giants     40.43     -74.01
# 1       Eagles    Eagles     39.57     -75.07
# 2     Dolphins      Jets     25.46     -80.12
# 3     Patriots  Patriots     42.21     -71.04
# 4     Steelers  Steelers     40.26     -80.00
# ...        ...       ...       ...        ...                    ...
# 1732  Panthers  Panthers     35.14     -80.50
# 1733   Broncos   Broncos     39.43    -105.01
# 1734   Broncos   Broncos     39.43    -105.01
# 1735  Panthers  Panthers     35.14     -80.50
# 1736   Broncos   Broncos     39.43    -105.01
#
#      weatherDesc cloudcover
# 0
# 1
# 2
# 3
# 4
# ...          ...        ...
# 1732
# 1733
# 1734
# 1735
# 1736
#
# [1737 rows x 13 columns]

# %%
for index, row in trial_df.iterrows():
    try:
        lat = row['Latitude']
        lng = row["Longitude"]
        date = row["Full Date"]
        location = f"{lat},{lng}"
        times = row["time_index"]
        print(location)
        print(date)
        print(times)
        
        T.sleep(3)
    except IndexError:
        print("error")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-24d0af03bc28> in <module>
# ----> 1 for index, row in trial_df.iterrows():
#       2     try:
#       3         lat = row['Latitude']
#       4         lng = row["Longitude"]
#       5         date = row["Full Date"]
#
# NameError: name 'trial_df' is not defined

# %%
# set up table 1 df
table_1 = clean_df.iloc[:80,:]
table_1
# Out:
#      Full Date    Time  time_conv  time_index Week          City Home Team  \
# 0   2008-09-04  7:08PM       1900          18    1      New York    Giants
# 1   2008-09-07  1:02PM       1300          12    1  Philadelphia    Eagles
# 2   2008-09-07  1:02PM       1300          12    1         Miami  Dolphins
# 3   2008-09-07  1:02PM       1300          12    1   New England  Patriots
# 4   2008-09-07  1:02PM       1300          12    1    Pittsburgh  Steelers
# ..         ...     ...        ...         ...  ...           ...       ...
# 75  2008-10-19  1:02PM       1300          12    7      New York    Giants
# 76  2008-10-19  1:02PM       1300          12    7       Chicago     Bears
# 77  2008-10-19  1:04PM       1300          12    7    Cincinnati   Bengals
# 78  2008-10-19  1:04PM       1300          12    7      Carolina  Panthers
# 79  2008-10-19  4:15PM       1600          15    7       Oakland   Raiders
#
#       Winner  Latitude  Longitude Starting Game Temp (F) weatherDesc  \
# 0     Giants     40.43     -74.01
# 1     Eagles     39.57     -75.07
# 2       Jets     25.46     -80.12
# 3   Patriots     42.21     -71.04
# 4   Steelers     40.26     -80.00
# ..       ...       ...        ...                    ...         ...
# 75    Giants     40.43     -74.01
# 76     Bears     41.53     -87.38
# 77  Steelers     39.06     -84.31
# 78  Panthers     35.14     -80.50
# 79   Raiders     37.47    -122.13
#
#    cloudcover
# 0
# 1
# 2
# 3
# 4
# ..        ...
# 75
# 76
# 77
# 78
# 79
#
# [80 rows x 13 columns]

# %%
base_url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=9b6272a2d2e34f45bab144757210906&q="
for index, row in table_1.iterrows():
    try:
        lat = row['Latitude']
        lng = row["Longitude"]
        date = row["Full Date"]
        time = row["time_index"]
        location = f"{lat},{lng}"
        weather_test = f"{base_url},{location}&date={date}&tp=1&format=json"
        weather_info = requests.get(weather_test).json()
        table_1.loc[index, "Starting Game Temp (F)"] = weather_info['data']['weather'][0]['hourly'][time]['tempF']
        table_1.loc[index, "weatherDesc"] = weather_info['data']['weather'][0]['hourly'][time]['weatherDesc']
        table_1.loc[index, "cloudcover"]= weather_info['data']['weather'][0]['hourly'][time]['cloudcover']
        
        #print(table_1.iloc[[index],10:])
        
        T.sleep(1.5)
    except (KeyError,IndexError):
        print("error")

print("completed")
# Out:
# error
# error
# error
# completed

# %%
table_1
# Out:
#      Full Date    Time  time_conv  time_index Week          City Home Team  \
# 0   2008-09-04  7:08PM       1900          18    1      New York    Giants
# 1   2008-09-07  1:02PM       1300          12    1  Philadelphia    Eagles
# 2   2008-09-07  1:02PM       1300          12    1         Miami  Dolphins
# 3   2008-09-07  1:02PM       1300          12    1   New England  Patriots
# 4   2008-09-07  1:02PM       1300          12    1    Pittsburgh  Steelers
# ..         ...     ...        ...         ...  ...           ...       ...
# 75  2008-10-19  1:02PM       1300          12    7      New York    Giants
# 76  2008-10-19  1:02PM       1300          12    7       Chicago     Bears
# 77  2008-10-19  1:04PM       1300          12    7    Cincinnati   Bengals
# 78  2008-10-19  1:04PM       1300          12    7      Carolina  Panthers
# 79  2008-10-19  4:15PM       1600          15    7       Oakland   Raiders
#
#       Winner  Latitude  Longitude Starting Game Temp (F)  \
# 0     Giants     40.43     -74.01                     72
# 1     Eagles     39.57     -75.07                     82
# 2       Jets     25.46     -80.12                     59
# 3   Patriots     42.21     -71.04                     82
# 4   Steelers     40.26     -80.00                     72
# ..       ...       ...        ...                    ...
# 75    Giants     40.43     -74.01                     68
# 76     Bears     41.53     -87.38                     86
# 77  Steelers     39.06     -84.31                     81
# 78  Panthers     35.14     -80.50                     55
# 79   Raiders     37.47    -122.13                     56
#
#                        weatherDesc cloudcover
# 0               {'value': 'Clear'}          0
# 1       {'value': 'Partly cloudy'}         38
# 2   {'value': 'Light rain shower'}         97
# 3       {'value': 'Partly cloudy'}         38
# 4               {'value': 'Sunny'}         14
# ..                             ...        ...
# 75              {'value': 'Sunny'}          0
# 76              {'value': 'Sunny'}          5
# 77              {'value': 'Sunny'}         15
# 78              {'value': 'Sunny'}          9
# 79           {'value': 'Overcast'}        100
#
# [80 rows x 13 columns]

# %%
table_1.to_csv("Table 1.csv",encoding="utf-8",index=False)

# %%
# run for table 2
table_2 = clean_df.iloc[80:155,:]

# %%
base_url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=9b6272a2d2e34f45bab144757210906&q="
for index, row in table_2.iterrows():
    try:
        lat = row['Latitude']
        lng = row["Longitude"]
        date = row["Full Date"]
        time = row["time_index"]
        location = f"{lat},{lng}"
        weather_test = f"{base_url},{location}&date={date}&tp=1&format=json"
        weather_info = requests.get(weather_test).json()
        table_2.loc[index, "Starting Game Temp (F)"] = weather_info['data']['weather'][0]['hourly'][time]['tempF']
        table_2.loc[index, "weatherDesc"] = weather_info['data']['weather'][0]['hourly'][time]['weatherDesc']
        table_2.loc[index, "cloudcover"]= weather_info['data']['weather'][0]['hourly'][time]['cloudcover']
        
        #print(table_2.iloc[index])
        
        T.sleep(1.5)
    except (KeyError,IndexError):
        print("error")

print("completed")
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
# error
# error
# error
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-20-40a344270641> in <module>
#       8         location = f"{lat},{lng}"
#       9         weather_test = f"{base_url},{location}&date={date}&tp=1&format=json"
# ---> 10         weather_info = requests.get(weather_test).json()
#      11         table_2.loc[index, "Starting Game Temp (F)"] = weather_info['data']['weather'][0]['hourly'][time]['tempF']
#      12         table_2.loc[index, "weatherDesc"] = weather_info['data']['weather'][0]['hourly'][time]['weatherDesc']
#
# /Applications/anaconda3/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# /Applications/anaconda3/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /Applications/anaconda3/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# /Applications/anaconda3/lib/python3.8/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
table_2
# Out:
#       Full Date    Time  time_conv  time_index Week          City   Home Team  \
# 80   2008-10-19  4:15PM       1600          15    7     Green Bay     Packers
# 81   2008-10-19  4:16PM       1600          15    7    Washington    Redskins
# 82   2008-10-19  8:23PM       2000          19    7     Tampa Bay  Buccaneers
# 83   2008-10-20  8:40PM       2000          19    7   New England    Patriots
# 84   2008-10-26  1:02PM       1300          12    8     Baltimore      Ravens
# ..          ...     ...        ...         ...  ...           ...         ...
# 495  2010-10-17  1:02PM       1300          12    6   New England    Patriots
# 496  2010-10-17  1:02PM       1300          12    6    Pittsburgh    Steelers
# 497  2010-10-17  1:02PM       1300          12    6       Chicago       Bears
# 498  2010-10-17  1:02PM       1300          12    6  Philadelphia      Eagles
# 499  2010-10-17  1:02PM       1300          12    6     Green Bay     Packers
#
#          Winner  Latitude  Longitude Starting Game Temp (F)  \
# 80      Packers     44.30     -88.01                     71
# 81     Redskins     38.54     -77.01                     61
# 82   Buccaneers       NaN        NaN                     74
# 83     Patriots     42.21     -71.04                     73
# 84       Ravens     39.17     -76.37                     84
# ..          ...       ...        ...                    ...
# 495    Patriots     42.21     -71.04
# 496    Steelers     40.26     -80.00
# 497    Seahawks     41.53     -87.38
# 498      Eagles     39.57     -75.07
# 499    Dolphins     44.30     -88.01
#
#                         weatherDesc cloudcover
# 80               {'value': 'Sunny'}          0
# 81               {'value': 'Sunny'}          0
# 82   {'value': 'Light rain shower'}         62
# 83               {'value': 'Clear'}         22
# 84               {'value': 'Sunny'}         10
# ..                              ...        ...
# 495
# 496
# 497
# 498
# 499
#
# [420 rows x 13 columns]

# %%
table_2.to_csv("Table 2.csv",encoding="utf-8",index=False)

# %%
table_3 = clean_df.iloc[155:495,:]

# %%
#run for table 3
table_3.head()
# Out:
#       Full Date    Time  time_conv  time_index Week          City Home Team  \
# 155  2008-11-30  4:15PM       1600          15   13   New England  Patriots
# 156  2008-12-04  8:15PM       2000          19   14     San Diego  Chargers
# 157  2008-12-07  1:02PM       1300          12   14       Chicago     Bears
# 158  2008-12-07  1:02PM       1300          12   14  Indianapolis     Colts
# 159  2008-12-07  1:02PM       1300          12   14     Green Bay   Packers
#
#        Winner  Latitude  Longitude Starting Game Temp (F) weatherDesc  \
# 155  Steelers     42.21     -71.04
# 156  Chargers     32.43    -118.09
# 157     Bears     41.53     -87.38
# 158     Colts     39.46     -86.09
# 159    Texans     44.30     -88.01
#
#     cloudcover
# 155
# 156
# 157
# 158
# 159

# %%
base_url = "http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=6cd0fcd19b014508966202712210906&q="
for index, row in table_3.iterrows():
    try:
        lat = row['Latitude']
        lng = row["Longitude"]
        date = row["Full Date"]
        time = row["time_index"]
        location = f"{lat},{lng}"
        weather_test = f"{base_url},{location}&date={date}&tp=1&format=json"
        weather_info = requests.get(weather_test).json()
        table_3.loc[index, "Starting Game Temp (F)"] = weather_info['data']['weather'][0]['hourly'][time]['tempF']
        table_3.loc[index, "weatherDesc"] = weather_info['data']['weather'][0]['hourly'][time]['weatherDesc']
        table_3.loc[index, "cloudcover"]= weather_info['data']['weather'][0]['hourly'][time]['cloudcover']
        
        #print(table_2.iloc[index])
        
        T.sleep(1.5)
    except (KeyError,IndexError):
        print("error")

print("completed")
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1700: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, v, pi)
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# error
# completed

# %%
table_3.to_csv("Table 3.csv",encoding="utf-8",index=False)

# %%
table_3 = clean_df.iloc[495:975,:]
table_3.head()
# Out:
#       Full Date    Time  time_conv  time_index Week          City Home Team  \
# 495  2010-10-17  1:02PM       1300          12    6   New England  Patriots
# 496  2010-10-17  1:02PM       1300          12    6    Pittsburgh  Steelers
# 497  2010-10-17  1:02PM       1300          12    6       Chicago     Bears
# 498  2010-10-17  1:02PM       1300          12    6  Philadelphia    Eagles
# 499  2010-10-17  1:02PM       1300          12    6     Green Bay   Packers
#
#        Winner  Latitude  Longitude Starting Game Temp (F) weatherDesc  \
# 495  Patriots     42.21     -71.04
# 496  Steelers     40.26     -80.00
# 497  Seahawks     41.53     -87.38
# 498    Eagles     39.57     -75.07
# 499  Dolphins     44.30     -88.01
#
#     cloudcover
# 495
# 496
# 497
# 498
# 499

# %%
#http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=6f2d4be584aa413f9df230512210306&q=45.53,-87.38&date=2008-09-08&tp=1&format=json

# %%
# done
table_1.head()
table_2.head()
table_3.head()
# Out:
#       Full Date    Time  time_conv  time_index Week          City Home Team  \
# 155  2008-11-30  4:15PM       1600          15   13   New England  Patriots
# 156  2008-12-04  8:15PM       2000          19   14     San Diego  Chargers
# 157  2008-12-07  1:02PM       1300          12   14       Chicago     Bears
# 158  2008-12-07  1:02PM       1300          12   14  Indianapolis     Colts
# 159  2008-12-07  1:02PM       1300          12   14     Green Bay   Packers
#
#        Winner  Latitude  Longitude Starting Game Temp (F)  \
# 155  Steelers     42.21     -71.04                     62
# 156  Chargers     32.43    -118.09                     29
# 157     Bears     41.53     -87.38                     82
# 158     Colts     39.46     -86.09                     63
# 159    Texans     44.30     -88.01                     51
#
#                            weatherDesc cloudcover
# 155                 {'value': 'Sunny'}          0
# 156         {'value': 'Partly cloudy'}         60
# 157  {'value': 'Patchy rain possible'}         46
# 158                 {'value': 'Sunny'}          0
# 159                 {'value': 'Sunny'}         12

# %%
table_4 = clean_df.iloc[495:975,:]
table_4.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8491ebbc773e> in <module>
#       1 table_4 = clean_df.iloc[495:975,:]
# ----> 2 table
#
# NameError: name 'table' is not defined
