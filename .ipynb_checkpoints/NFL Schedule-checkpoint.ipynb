# %%
# Import Libraries
import pandas as pd


from bs4 import BeautifulSoup as bs

#from api_keys import weather_api_key

# %%
from datetime import datetime

# %%
# import and set up CSV
schedule_csv = "Resources/NFLSchedule.csv"

full_schedule = pd.read_csv(schedule_csv)
full_schedule.head()
# Out:
#    Unnamed: 0  Year Week  Day          Date Time           Winner/tie  \
# 0           0  1967    1  Sun  September 17  NaN  Pittsburgh Steelers
# 1           1  1967    1  Sun  September 17  NaN      Baltimore Colts
# 2           2  1967    1  Sun  September 17  NaN    Green Bay Packers
# 3           3  1967    1  Sun  September 17  NaN  Philadelphia Eagles
# 4           4  1967    1  Sun  September 17  NaN  San Francisco 49ers
#
#              Loser/tie  PtsW  PtsL  YdsW  TOW  YdsL  TOL             HomeTeam  \
# 0        Chicago Bears    41    13   393    2    95    6  Pittsburgh Steelers
# 1      Atlanta Falcons    38    31   508    2   303    5      Baltimore Colts
# 2        Detroit Lions    17    17   306    5   233    1    Green Bay Packers
# 3  Washington Redskins    35    24   426    2   388    1  Philadelphia Eagles
# 4    Minnesota Vikings    27    21   360    1   335    3    Minnesota Vikings
#
#               AwayTeam
# 0        Chicago Bears
# 1      Atlanta Falcons
# 2        Detroit Lions
# 3  Washington Redskins
# 4  San Francisco 49ers

# %%
# remove columns
removed_col_df = full_schedule[['Year','Week','Date','Time','Winner/tie','HomeTeam']]
removed_col_df.head()
# Out:
#    Year Week          Date Time           Winner/tie             HomeTeam
# 0  1967    1  September 17  NaN  Pittsburgh Steelers  Pittsburgh Steelers
# 1  1967    1  September 17  NaN      Baltimore Colts      Baltimore Colts
# 2  1967    1  September 17  NaN    Green Bay Packers    Green Bay Packers
# 3  1967    1  September 17  NaN  Philadelphia Eagles  Philadelphia Eagles
# 4  1967    1  September 17  NaN  San Francisco 49ers    Minnesota Vikings

# %%
full_date_df = removed_col_df
full_date_df["Full Date"] = full_schedule['Year'].map(str) + '-' + full_schedule["Date"].map(str)
full_date_df.head()
# Out:
# <ipython-input-5-71af9b739d5f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_date_df["Full Date"] = full_schedule['Year'].map(str) + '-' + full_schedule["Date"].map(str)
#    Year Week          Date Time           Winner/tie             HomeTeam  \
# 0  1967    1  September 17  NaN  Pittsburgh Steelers  Pittsburgh Steelers
# 1  1967    1  September 17  NaN      Baltimore Colts      Baltimore Colts
# 2  1967    1  September 17  NaN    Green Bay Packers    Green Bay Packers
# 3  1967    1  September 17  NaN  Philadelphia Eagles  Philadelphia Eagles
# 4  1967    1  September 17  NaN  San Francisco 49ers    Minnesota Vikings
#
#            Full Date
# 0  1967-September 17
# 1  1967-September 17
# 2  1967-September 17
# 3  1967-September 17
# 4  1967-September 17

# %%
full_date_df["Full Date"] = pd.to_datetime(full_date_df["Full Date"], format="%Y-%B %d")
# Out:
# <ipython-input-6-b138d2b2d18b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   full_date_df["Full Date"] = pd.to_datetime(full_date_df["Full Date"], format="%Y-%B %d")

# %%
full_date_df.head()
# Out:
#    Year Week          Date Time           Winner/tie             HomeTeam  \
# 0  1967    1  September 17  NaN  Pittsburgh Steelers  Pittsburgh Steelers
# 1  1967    1  September 17  NaN      Baltimore Colts      Baltimore Colts
# 2  1967    1  September 17  NaN    Green Bay Packers    Green Bay Packers
# 3  1967    1  September 17  NaN  Philadelphia Eagles  Philadelphia Eagles
# 4  1967    1  September 17  NaN  San Francisco 49ers    Minnesota Vikings
#
#    Full Date
# 0 1967-09-17
# 1 1967-09-17
# 2 1967-09-17
# 3 1967-09-17
# 4 1967-09-17

# %%
# filter for year 2007< since API historical can only go back that far
year_filter_df = full_date_df[full_date_df['Year']> 2007]
year_filter_df.head()
# Out:
#       Year Week         Date    Time            Winner/tie  \
# 9136  2008    1  September 4  7:08PM       New York Giants
# 9137  2008    1  September 7  1:02PM   Philadelphia Eagles
# 9138  2008    1  September 7  1:02PM         New York Jets
# 9139  2008    1  September 7  1:02PM  New England Patriots
# 9140  2008    1  September 7  1:02PM   Pittsburgh Steelers
#
#                   HomeTeam  Full Date
# 9136       New York Giants 2008-09-04
# 9137   Philadelphia Eagles 2008-09-07
# 9138        Miami Dolphins 2008-09-07
# 9139  New England Patriots 2008-09-07
# 9140   Pittsburgh Steelers 2008-09-07

# %%
#year_filter_df["Time"] = year_filter_df["Time"].astype(str)

# %%
city_split = year_filter_df
city_split[["City","Home Team"]] = year_filter_df["HomeTeam"].str.rsplit(n=1, expand=True)
city_split[["Winning City","Winner"]] = year_filter_df["Winner/tie"].str.rsplit(n=1, expand=True)
city_split.head()
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#       Year Week         Date    Time            Winner/tie  \
# 9136  2008    1  September 4  7:08PM       New York Giants
# 9137  2008    1  September 7  1:02PM   Philadelphia Eagles
# 9138  2008    1  September 7  1:02PM         New York Jets
# 9139  2008    1  September 7  1:02PM  New England Patriots
# 9140  2008    1  September 7  1:02PM   Pittsburgh Steelers
#
#                   HomeTeam  Full Date          City Home Team  Winning City  \
# 9136       New York Giants 2008-09-04      New York    Giants      New York
# 9137   Philadelphia Eagles 2008-09-07  Philadelphia    Eagles  Philadelphia
# 9138        Miami Dolphins 2008-09-07         Miami  Dolphins      New York
# 9139  New England Patriots 2008-09-07   New England  Patriots   New England
# 9140   Pittsburgh Steelers 2008-09-07    Pittsburgh  Steelers    Pittsburgh
#
#         Winner
# 9136    Giants
# 9137    Eagles
# 9138      Jets
# 9139  Patriots
# 9140  Steelers

# %%
city_split["New Time"] = city_split["Time"].str.split(":", expand=True)
city_split.head()
# Out:
# <ipython-input-24-3372e96008e8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   city_split["New Time"] = city_split["Time"].str.split(":", expand=True)
#       Year Week         Date    Time            Winner/tie  \
# 9136  2008    1  September 4  7:08PM       New York Giants
# 9137  2008    1  September 7  1:02PM   Philadelphia Eagles
# 9138  2008    1  September 7  1:02PM         New York Jets
# 9139  2008    1  September 7  1:02PM  New England Patriots
# 9140  2008    1  September 7  1:02PM   Pittsburgh Steelers
#
#                   HomeTeam  Full Date          City Home Team  Winning City  \
# 9136       New York Giants 2008-09-04      New York    Giants      New York
# 9137   Philadelphia Eagles 2008-09-07  Philadelphia    Eagles  Philadelphia
# 9138        Miami Dolphins 2008-09-07         Miami  Dolphins      New York
# 9139  New England Patriots 2008-09-07   New England  Patriots   New England
# 9140   Pittsburgh Steelers 2008-09-07    Pittsburgh  Steelers    Pittsburgh
#
#         Winner New Time
# 9136    Giants        7
# 9137    Eagles        1
# 9138      Jets        1
# 9139  Patriots        1
# 9140  Steelers        1

# %%
setup_df = city_split[["Full Date","New Time",'Week',"City","Home Team","Winner"]]
setup_df.head()
# Out:
#       Full Date New Time Week          City Home Team    Winner
# 9136 2008-09-04        7    1      New York    Giants    Giants
# 9137 2008-09-07        1    1  Philadelphia    Eagles    Eagles
# 9138 2008-09-07        1    1         Miami  Dolphins      Jets
# 9139 2008-09-07        1    1   New England  Patriots  Patriots
# 9140 2008-09-07        1    1    Pittsburgh  Steelers  Steelers

# %%
indoor_city = ["Dallas","New Orleans", "Atlanta","Minnesota","Detroit","Houston"]

# %%
setup_df = setup_df.reset_index()
set_table
# Out:
#       index  Full Date New Time       Week           City Home Team    Winner
# 0      9136 2008-09-04        7          1       New York    Giants    Giants
# 1      9137 2008-09-07        1          1   Philadelphia    Eagles    Eagles
# 2      9138 2008-09-07        1          1          Miami  Dolphins      Jets
# 3      9139 2008-09-07        1          1    New England  Patriots  Patriots
# 4      9140 2008-09-07        1          1     Pittsburgh  Steelers  Steelers
# ...     ...        ...      ...        ...            ...       ...       ...
# 3199  12335 2019-01-12        3   Division    Kansas City    Chiefs    Chiefs
# 3200  12336 2019-01-12        6   Division      Green Bay   Packers   Packers
# 3201  12337 2019-01-19        3  ConfChamp    Kansas City    Chiefs    Chiefs
# 3202  12338 2019-01-19        6  ConfChamp  San Francisco     49ers     49ers
# 3203  12339 2019-02-02        6  SuperBowl    Kansas City    Chiefs    Chiefs
#
# [3204 rows x 7 columns]

# %%
# fix time to display in hhmm (1am is 100, 3pm is 1500)

# %%
# Out:
#       Full Date    Time Week          City Home Team    Winner
# 9136 2008-09-04  7:08PM    1      New York    Giants    Giants
# 9137 2008-09-07  1:02PM    1  Philadelphia    Eagles    Eagles
# 9138 2008-09-07  1:02PM    1         Miami  Dolphins      Jets
# 9139 2008-09-07  1:02PM    1   New England  Patriots  Patriots
# 9140 2008-09-07  1:02PM    1    Pittsburgh  Steelers  Steelers

# %%
final_table = final_table[["Full Date","New Time",'Week',"City","Home Team","Winner"]]
final_table.head()
# Out:
#    Full Date New Time Week          City Home Team    Winner
# 0 2008-09-04        7    1      New York    Giants    Giants
# 1 2008-09-07        1    1  Philadelphia    Eagles    Eagles
# 2 2008-09-07        1    1         Miami  Dolphins      Jets
# 3 2008-09-07        1    1   New England  Patriots  Patriots
# 4 2008-09-07        1    1    Pittsburgh  Steelers  Steelers

# %%
final_table = final_table[["Full Date","Week","Time","City","Home Team","Winner"]]
final_table
final_table.to_csv("NFL_Schedule.csv",encoding="utf-8",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-7eac11ab632b> in <module>
# ----> 1 final_table = final_table[["Full Date","Week","Time","City","Home Team","Winner"]]
#       2 final_table
#       3 final_table.to_csv("NFL_Schedule.csv",encoding="utf-8",index=False)
#
# NameError: name 'final_table' is not defined

# %%
final_table = setup_df.reset_index()
final_table
# Out:
#       index  Full Date    Time       Week           City Home Team    Winner
# 0      9136 2008-09-04  7:08PM          1       New York    Giants    Giants
# 1      9137 2008-09-07  1:02PM          1   Philadelphia    Eagles    Eagles
# 2      9138 2008-09-07  1:02PM          1          Miami  Dolphins      Jets
# 3      9139 2008-09-07  1:02PM          1    New England  Patriots  Patriots
# 4      9140 2008-09-07  1:02PM          1     Pittsburgh  Steelers  Steelers
# ...     ...        ...     ...        ...            ...       ...       ...
# 3199  12335 2019-01-12  3:05PM   Division    Kansas City    Chiefs    Chiefs
# 3200  12336 2019-01-12  6:40PM   Division      Green Bay   Packers   Packers
# 3201  12337 2019-01-19  3:05PM  ConfChamp    Kansas City    Chiefs    Chiefs
# 3202  12338 2019-01-19  6:40PM  ConfChamp  San Francisco     49ers     49ers
# 3203  12339 2019-02-02  6:30PM  SuperBowl    Kansas City    Chiefs    Chiefs
#
# [3204 rows x 7 columns]

# %%
playoffs = ["WildCard","Division","ConfChamp","SuperBowl"]
indoor_teams = ["Cowboys","Saints","Falcons","Vikings","Lions","Texans"]
indoor_city = ["Dallas","New Orleans", "Atlanta","Minnesota","Detroit","Houston"]

# %%
base_url = https://api.worldweatheronline.com/premium/v1/past-weather.ashx

# %%
# http://www.worldweatheronline.com/feed/wwoConditionCodes.txt
